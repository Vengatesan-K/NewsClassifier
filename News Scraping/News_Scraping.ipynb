# %% [markdown]
# <table align="center" width="100%">
#     <tr>
#         <td>
#             <div align="center">
#                 <table>
#                     <tr>
#                         <td>
#                             <img src="2018-09-17-figure1.png" style="max-width: 60px; display: block;">
#                         </td>
#                         <td>
#                             <font color=#3FC3F5 size="5px">
#                                 <b>News Web Scraping Using BeautifulSoup
# </b>
#                             </font>
#                         </td>
#                     </tr>
#                 </table>
#             </div>
#             <p style="text-align:center; margin-top: 10px;">
#                 <span style="color: #3FC3F5;">Copyright (©)  Vengatesan-K. All Rights Reserved.</span>
#             </p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="4%">
#             <img src="scr.jpg">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>Web Scraping</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# > - **Choose news websites (e.g., BBC, The Hindu, Times Now, CNN) and use web scraping
# tools or libraries (e.g., BeautifulSoup,Selenium) to extract news articles.**
# >
# > - **Retrieve the title and content of each news article. Ensure that you have a diverse dataset
# covering various topics.**

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="4%">
#             <img src="https://icons.veryicon.com/png/o/system/hywf-background-icon/import-37.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>Import Libraries</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %% [markdown]
# > News Scrapped and Collected at 02/01/2024

# %%
URL = 'https://www.bbc.com/news'
response = requests.get(URL)
print("The response code is :",response)


soup = BeautifulSoup(response.content,'html.parser')

headlines = soup.find_all('h3')

print(headlines)
# Out:
# The response code is : <Response [200]>
# ...

# %% [markdown]
# <table align="center">
#     <tr>
#         <td width="20%">
#             <img src="logo_toi.png">
#         </td>
#         <td>
#         </td>
#     </tr>
# </table>

# %%
def timesofindia():
    url = "https://timesofindia.indiatimes.com/home/headlines"
    page_request = requests.get(url)
    data = page_request.content
    soup = BeautifulSoup(data,"html.parser")

    counter = 0
    for divtag in soup.find_all('div', {'class': 'headlines-list'}):
        for ultag in divtag.find_all('ul', {'class': 'clearfix'}):
            if (counter <= 10):
                for litag in ultag.find_all('li'):
                    counter = counter + 1
                    print(str(counter) + litag.find('a')['href'])

# %%
timesofindia()
# Out:
# 1/more-direct-intl-connectivity-new-circuits-ease-of-visas-will-bring-back-the-foreign-tourist/articleshow/106457074.cms
# 2https://www.gadgetsnow.com/slideshows/14-smartphones-from-samsung-oneplus-redmi-and-others-that-are-set-to-launch-in-january/photolist/106459422.cms
# 3/sports/cricket/india-in-south-africa/south-africa-aim-for-dean-elgars-test-farewell-victory-against-india-in-series-decider/articleshow/106463083.cms
# 4/world/rest-of-world/south-korean-opposition-party-leader-lee-jae-myung-stabbed-in-neck-during-visit-to-busan/articleshow/106462941.cms
# 5/india/high-court-not-inclined-to-give-teesta-relief-in-grave-digging-case/articleshow/106459572.cms
# 6/india/after-us-india-second-country-to-send-dedicated-sat-to-study-black-holes/articleshow/106459602.cms
# 7/city/lucknow/trust-members-selected-ram-lalla-idol-on-december-29/articleshow/106459670.cms
# 8/gadgets-news/this-is-how-india-ordered-on-zomato-swiggy-this-new-years-eve/articleshow/106457497.cms
# ...

# %%
url = 'https://timesofindia.indiatimes.com/briefs'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <h2> elements as headings
headings = soup.find_all('h2')

# Find all <p> elements as content
contents = soup.find_all('p')

# Extracting text from headings and contents
headings_text = [heading.get_text().strip() for heading in headings]
contents_text = [content.get_text().strip() for content in contents]

# Zipping headings and contents together
data = zip(headings_text, contents_text)

# Specify the CSV file name
csv_filename = 'headings_contents.csv'

# Writing data to CSV file
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    # Write header row
    writer.writerow(['Heading', 'Content'])
    # Write rows of heading and content pairs
    writer.writerows(data)

print(f"Data has been saved to '{csv_filename}'.")
# Out:
# Data has been saved to 'headings_contents.csv'.

# %%
url = 'https://timesofindia.indiatimes.com/briefs'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <h2> elements as headings
headings = soup.find_all('h2')

# Create a dictionary to store heading-content pairs
data_dict = {}

# Loop through each heading and find its corresponding <p> content
for heading in headings:
    # Get the text of the heading
    heading_text = heading.get_text().strip()
    # Find the next <p> element after the current heading
    next_p = heading.find_next('p')
    if next_p:
        # Get the text of the content
        content_text = next_p.get_text().strip()
        # Store heading-content pair in the dictionary
        data_dict[heading_text] = content_text

# Specify the CSV file name
csv_filename = 'headings_contents1.csv'

# Writing data to CSV file
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    # Write header row
    writer.writerow(['Heading', 'Content'])
    # Write rows of heading and content pairs
    for heading, content in data_dict.items():
        writer.writerow([heading, content])

print(f"Data has been saved to '{csv_filename}'.")
# Out:
# Data has been saved to 'headings_contents1.csv'.

# %%
TOI = pd.read_csv('headings_contents1.csv')
TOI
# Out:
#                                               Heading  \
# 0                                     TOI TimesPoints
# 1                 Visit TOI Daily & Earn Times Points
# 2   'George Soros becomes latest victim of prank 9...
# 3   Australia opt for unchanged line-up in Warner'...
# 4   'Bill Clinton among big names to be unmasked i...
# ..                                                ...
# 58                                    Trending topics
# 59                                       Follow us on
# 60                                   download toi app
# 61                              More from our network
# 62                                     Hot on the web
#
#                                               Content
# 0   You must login to keep earning daily check-in ...
# 1   Billionaire George Soros' estate in New York w...
# 2   Billionaire George Soros' estate in New York w...
# 3   Australia have decided not to include a second...
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="5%">
#             <img src="CNN.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:150%">
#                 <font color="red">
#                     <b>News</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
url = 'https://edition.cnn.com/world'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all elements with class="container__headline-text" and data-editable="headline"
    headlines = soup.find_all(class_="container__headline-text", attrs={"data-editable": "headline"})

    # Print the headlines
    for headline in headlines:
        print(headline.text.strip())
else:
    print("Failed to retrieve the webpage")
# Out:
# Denmark’s Crown Princess Mary to become first Australian-born Queen
# Israel’s top court strikes down key part of judicial overhaul, reigniting divisions as war rages
# Multiple dead in powerful Japan earthquake
# South Korean opposition leader attacked with knife during press conference
# Israel to pull some troops from Gaza in war against Hamas
# Massive earthquake hits Japan, triggering tsunami warnings
# Democratic Republic of Congo President Tshisekedi re-elected after contested poll
# Russia retaliates against Ukraine after 24 killed in border city
# Navalny sends ‘Arctic hugs and polar greetings’ from Siberian prison in New Year’s Eve message
# Follow the New Year around the world
# As 2023 draws to a close, Putin wants the world to think he is winning
# Russia says toll from Ukrainian shelling on border city has risen to 24 as it vows to retaliate
# Germany and France beef up security ahead of New Year’s Eve celebrations
# CNN coverage of COP28 UAE
# ...

# %%
url = 'https://edition.cnn.com/2023/12/22/americas/nicaragua-bishop-arrest-intl-hnk/index.html'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all elements with class="paragraph inline-placeholder"
    paragraphs = soup.find_all(class_="paragraph inline-placeholder")

    for paragraph in paragraphs:
        # Find the nearest heading for each paragraph
        title_heading = paragraph.find_previous(class_="container__headline-text")
        if title_heading:
            print(f"\nTitle: {title_heading.text.strip()}")

        # Extract and print text content from each paragraph element
        print(f"Content: {paragraph.text.strip()}")

else:
    print("Failed to retrieve the webpage")
# Out:
# Content: A second bishop was arrested by Nicaraguan authorities on Thursday, two sources told CNN, amid a far-reaching crackdown on opposition figures and the Catholic Church by the government of President Daniel Ortega.
# Content: Bishop Isidoro Mora, of the Siuna church on the country’s Caribbean coast, was arrested after taking part in a mass to celebrate the anniversary of the Matagalpa church, the sources said.
# Content: CNN has reached out to the Nicaraguan government for further details on Mora’s legal situation and arrest.
# Content: One of the sources said they had witnessed the moments leading up to the arrest, telling CNN that Mora had briefly mentioned the detained bishop and vocal government critic Rolando Álvarez during a 10-minute homily.
# Content: The source quoted Mora as saying “we are here praying for Matagalpa church, praying for bishop Rolando.”
# Content: The source added, “Unfortunately, (Mora) was arrested the next day.”
# ...

# %%
url = 'https://edition.cnn.com/2023/12/22/americas/nicaragua-bishop-arrest-intl-hnk/index.html'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all elements with class="headline__text inline-placeholder"
    headlines = soup.find_all(class_="headline__text inline-placeholder")

    for headline in headlines:
        # Extract and print heading text
        heading_text = headline.text.strip()
        print(f"\nHeading: {heading_text}")

        # Find the associated content for each heading
        # Assuming the content is in the sibling element
        content = headline.find_next(class_="paragraph inline-placeholder")
        if content:
            content_text = content.text.strip()
            print(f"Content: {content_text}")
        else:
            print("Content not found")

else:
    print("Failed to retrieve the webpage")
# Out:
# Heading: Nicaragua arrests second bishop as crackdown on Catholic church intensifies
# Content: A second bishop was arrested by Nicaraguan authorities on Thursday, two sources told CNN, amid a far-reaching crackdown on opposition figures and the Catholic Church by the government of President Daniel Ortega.

# %%
url = 'https://edition.cnn.com/'

# Send a GET request to the URL
response = requests.get(url)

# List to store found links
found_links = []

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all <a> tags with the specified class
    links = soup.find_all('a', class_="container__link container__link--type-article container_lead-plus-headlines__link container_lead-plus-headlines__left container_lead-plus-headlines__light")

    for link in links:
        # Extract the href attribute
        link_href = link.get('href')

        # Append found link to the list
        if link_href:
            found_links.append(link_href)

else:
    print("Failed to retrieve the main webpage")

# Display found links
found_links
# Out:
# ['/2024/01/01/asia/japan-earthquake-tsunami-warning-intl-hnk/index.html',
#  '/2024/01/02/europe/denmark-crown-princess-mary-australia-intl-hnk/index.html',
#  '/2024/01/02/europe/denmark-crown-princess-mary-australia-intl-hnk/index.html',
#  '/us/missing-exchange-student-utah-found/index.html',
#  '/2024/01/01/middleeast/israel-court-judicial-overhaul-intl/index.html',
#  '/2024/01/01/politics/uss-gerald-ford-return-mediterranean-hnk/index.html',
#  '/2023/12/31/opinions/supreme-court-trump-2024-election-states-remove-ballot-mark/index.html',
#  '/2024/01/01/opinions/dave-chappelle-comedy-walks-offstage-cellphone-camera-obeidallah/index.html',
#  '/2024/01/01/sport/melissa-hoskins-dies-hit-by-car-spt-intl/index.html',
#  '/2024/01/01/sport/melissa-hoskins-dies-hit-by-car-spt-intl/index.html',
#  '/2023/12/31/us/colorado-mother-double-murder-arrest/index.html',
#  '/2024/01/01/politics/senate-race-rankings-january-2024/index.html',
# ...

# %%
url = 'https://edition.cnn.com/'

# Send a GET request to the URL
response = requests.get(url)

# List to store section URLs
section_urls = []

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all elements with class="header__nav-item-link"
    section_links = soup.find_all(class_="header__nav-item")

    for link in section_links:
        section_url = link.find('a')['href']
        section_urls.append(section_url)

else:
    print("Failed to retrieve the main webpage")

# Display section URLs
section_urls
# Out:
# ['https://edition.cnn.com/us',
#  'https://edition.cnn.com/world',
#  'https://edition.cnn.com/politics',
#  'https://edition.cnn.com/business',
#  'https://edition.cnn.com/opinions',
#  'https://edition.cnn.com/health',
#  'https://edition.cnn.com/entertainment',
#  'https://edition.cnn.com/style',
#  'https://edition.cnn.com/travel',
#  'https://edition.cnn.com/sports']

# %%
# Assuming 'section_urls' contains section URLs from the previous step
# List to store article URLs
article_urls = []

# Loop through each section URL and extract article URLs
for section_url in section_urls:
    response = requests.get(section_url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all links containing article URLs within the section using specified classes
        article_links = soup.find_all('a', class_="container__link container__link--type-article container_lead-plus-headlines__link")

        # Extract and append article URLs
        for link in article_links:
            article_url = link.get('href')
            article_urls.append(url + article_url)  # Store the complete article URL

    else:
        print(f"Failed to retrieve content from the section: {url + section_url}")

# Display article URLs
article_urls
# Out:
# ['https://edition.cnn.com//2024/01/02/us/new-jersey-migrant-buses-nyc/index.html',
#  'https://edition.cnn.com//2024/01/02/us/new-jersey-migrant-buses-nyc/index.html',
#  'https://edition.cnn.com//2024/01/01/us/kodak-center-new-york-car-crash/index.html',
#  'https://edition.cnn.com//us/missing-exchange-student-utah-found/index.html',
#  'https://edition.cnn.com//2023/12/31/us/hawaii-shark-attack-trnd/index.html',
#  'https://edition.cnn.com//2024/01/01/us/gender-neutral-toy-aisles-are-now-law-in-california/index.html',
#  'https://edition.cnn.com//2023/12/31/us/sacramento-child-shooting/index.html',
#  'https://edition.cnn.com//2023/12/31/us/colorado-mother-double-murder-arrest/index.html',
#  'https://edition.cnn.com//2023/12/31/us/house-explosion-michigan-washtenaw/index.html',
#  'https://edition.cnn.com//2023/12/29/us/iowa-law-books-lgbtq-judge/index.html',
#  'https://edition.cnn.com//2023/12/29/us/iowa-law-books-lgbtq-judge/index.html',
# ...

# %%
article_links = soup.find_all('a', class_=["class1", "class2"])

# %%
# Assuming 'section_urls' contains section URLs from the previous step
# List to store article URLs
article_urls = []

# Loop through each section URL and extract article URLs
for section_url in section_urls:
    response = requests.get(section_url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all links containing article URLs within the section using specified classes
        article_links = soup.find_all('a', class_=["container__link container__link--type-article", "container_lead-plus-headlines__link"])

        # Extract and append article URLs
        for link in article_links:
            article_url = link.get('href')
            article_urls.append(url + article_url)  # Store the complete article URL

    else:
        print(f"Failed to retrieve content from the section: {url + section_url}")

# Display article URLs
article_urls
# Out:
# ['https://edition.cnn.com//2024/01/02/us/new-jersey-migrant-buses-nyc/index.html',
#  'https://edition.cnn.com//2024/01/02/us/new-jersey-migrant-buses-nyc/index.html',
#  'https://edition.cnn.com//2024/01/01/us/kodak-center-new-york-car-crash/index.html',
#  'https://edition.cnn.com//us/missing-exchange-student-utah-found/index.html',
#  'https://edition.cnn.com//2023/12/31/us/hawaii-shark-attack-trnd/index.html',
#  'https://edition.cnn.com//2024/01/01/us/gender-neutral-toy-aisles-are-now-law-in-california/index.html',
#  'https://edition.cnn.com//2023/12/31/us/sacramento-child-shooting/index.html',
#  'https://edition.cnn.com//2023/12/31/us/colorado-mother-double-murder-arrest/index.html',
#  'https://edition.cnn.com//2023/12/31/us/house-explosion-michigan-washtenaw/index.html',
#  'https://edition.cnn.com//2023/12/29/us/iowa-law-books-lgbtq-judge/index.html',
#  'https://edition.cnn.com//2023/12/29/us/iowa-law-books-lgbtq-judge/index.html',
# ...

# %%
# Assuming 'article_urls' contains extracted article URLs from Step 2
for article_url in article_urls:
    response = requests.get(article_url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract and display heading and content
        heading = soup.find(class_="headline__text inline-placeholder")
        content = soup.find(class_="paragraph inline-placeholder")

        if heading and content:
            print("\n--- New Article ---")
            print(f"Heading: {heading.text.strip()}")
            print(f"Content: {content.text.strip()}")
        else:
            print("Heading or content not found for this article")

    else:
        print(f"Failed to retrieve content from the article: {article_url}")

# %%
articles_data = []

for article_url in article_urls:
    response = requests.get(article_url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract and display heading and content
        heading = soup.find(class_="headline__text inline-placeholder")
        content = soup.find(class_="paragraph inline-placeholder")

        if heading and content:
            articles_data.append({
                "Heading": heading.text.strip(),
                "Content": content.text.strip()
            })
        else:
            articles_data.append({
                "Heading": "Heading not found",
                "Content": "Content not found"
            })

    else:
        articles_data.append({
            "Heading": "Failed to retrieve content",
            "Content": f"Failed URL: {article_url}"
        })

# Save extracted headings and content as a CSV file
csv_file = 'articles_data.csv'

with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    fieldnames = ['Heading', 'Content']
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    
    writer.writeheader()
    for article in articles_data:
        writer.writerow(article)

print(f"Data saved to {csv_file}")
# Out:
# Data saved to articles_data.csv

# %%
CNN = pd.read_csv('articles_data.csv')
CNN
# Out:
#                                                Heading  \
# 0                           Failed to retrieve content
# 1                           Failed to retrieve content
# 2                           Failed to retrieve content
# 3    Missing exchange student found cold and scared...
# 4                           Failed to retrieve content
# ..                                                 ...
# 425                         Failed to retrieve content
# 426                         Failed to retrieve content
# 427                         Failed to retrieve content
# 428                         Failed to retrieve content
# 429                         Failed to retrieve content
#
#                                                Content
# 0    Failed URL: https://edition.cnn.com//2024/01/0...
# 1    Failed URL: https://edition.cnn.com//2024/01/0...
# 2    Failed URL: https://edition.cnn.com//2024/01/0...
# 3    Utah police say they found a teenage Chinese e...
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="bbcnews.3.o.png">
#         </td>
#         <td>
#         </td>
#     </tr>
# </table>

# %%
# Function to scrape individual section of the website
def scrape_section_data(section_url):
    # Send a GET request to the section URL
    response = requests.get(section_url)
    section_data = []

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')
        articles = soup.find_all('div', class_='gs-c-promo')

        # Extract titles and content of each article in the section
        for article in articles:
            title_element = article.find('h3', class_='gs-c-promo-heading__title')
            title = title_element.text.strip() if title_element else 'No title'

            content_element = article.find('p', class_='gs-c-promo-summary')
            content = content_element.text.strip() if content_element else 'No content available'

            section_data.append({'Title': title, 'Content': content})

    else:
        print(f'Failed to fetch data from {section_url}')

    return section_data

# %%
# Function to save data to CSV file
def save_to_csv(data, file_name='bbc_news_scrap.csv'):
    with open(file_name, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['Title', 'Content']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Write rows
        for row in data:
            writer.writerow(row)

    print(f"Data saved to '{file_name}'")

# %%
# Function to scrape the BBC News website
def scrape_bbc_news():
    base_url = 'https://www.bbc.com'
    url = 'https://www.bbc.com/news'
    data = []

    # Send a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')
        sections = soup.find_all('a', class_='nw-o-link')

        # Iterate through sections and scrape data
        for section in sections:
            section_name = section.text.strip()
            section_link = urljoin(base_url, section['href'])

            if section_link.startswith(base_url):
                print(f"Scraping articles from '{section_name}' section...")
                section_data = scrape_section_data(section_link)
                data.extend(section_data)
                print("\n")

        # Save data to CSV file
        save_to_csv(data)

    else:
        print('Failed to fetch data from BBC News')

# %%
# Call the function to initiate scraping and save data to CSV
scrape_bbc_news()
# Out:
# Scraping articles from 'HomeHome selected' section...
#
#
# Scraping articles from 'Israel-Gaza war' section...
#
#
# Scraping articles from 'War in Ukraine' section...
#
#
# Scraping articles from 'Climate' section...
#
#
# Scraping articles from 'Video' section...
#
#
# Scraping articles from 'World' section...
#
#
# Scraping articles from 'Asia' section...
#
#
# Scraping articles from 'UK' section...
#
#
# Scraping articles from 'Business' section...
#
#
# Scraping articles from 'Tech' section...
#
#
# Scraping articles from 'Science' section...
#
#
# Scraping articles from 'Entertainment & Arts' section...
#
#
# Scraping articles from 'Health' section...
#
#
# Scraping articles from 'World News TV' section...
#
#
# Scraping articles from 'In Pictures' section...
#
#
# Scraping articles from 'BBC Verify' section...
#
#
# Scraping articles from 'Newsbeat' section...
#
#
# Scraping articles from 'HomeHome selected' section...
#
#
# ...

# %%
BBC = pd.read_csv('bbc_news_scrap.csv')
BBC
# Out:
#                                                   Title  \
# 0     Death toll in Japan earthquake hits 30 as sear...
# 1              Opposition leader stabbed in South Korea
# 2        What a century of earthquakes has taught Japan
# 3     HK mogul Jimmy Lai pleads not guilty in securi...
# 4      Australian jailed in Iraq reaches grim milestone
# ...                                                 ...
# 2458        A dish to start the year with a clean slate
# 2459     The Scandi artist who created a 'soulful home'
# 2460          The problem of thinking in straight lines
# 2461      Ten major events that shaped business in 2023
# 2462            How three widows came to rule Champagne
#
#                                                 Content
# 0     Japan's prime minister, Fumio Kishida, says th...
# 1     Lee Jae-myung was stabbed in the neck at a new...
# 2     Monday's quake renewed Japan's collective trau...
# 3     Jimmy Lai pleads not guilty to breaching natio...
# ...

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="12%">
#             <img src="Times_Now.png">
#         </td>
#         <td>
#         </td>
#     </tr>
# </table>

# %%
url = 'https://www.timesnownews.com/latest-news'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <a> elements with class 'undefined'
article_links = soup.find_all('a', class_='undefined')

# Extracting href attribute values from article links
article_urls = [link.get('href') for link in article_links]

# Displaying the article URLs
for url in article_urls:
    print(url)
# Out:
# https://www.timesnownews.com/technology-science/how-to/how-to-check-if-someone-has-blocked-you-on-instagram-article-106467097
# https://www.timesnownews.com/technology-science/cybersecurity/filled-a-cybercrime-complaint-heres-how-to-check-its-status-online-article-106472948
# https://www.timesnownews.com/technology-science/how-to/filled-a-cybercrime-complaint-heres-how-to-check-its-status-online-article-106475646
# https://www.timesnownews.com/business-economy/economy/pakistan-awaits-usd-700-million-imf-tranche-d-day-on-this-date-details-article-106474842
# https://www.timesnownews.com/entertainment-news/tv/new-parents-rubina-dilaik-abhinav-shukla-hold-twin-daughters-close-as-they-ring-in-new-year-2024-article-106473360
# https://www.timesnownews.com/technology-science/how-to/forget-whatsapp-share-live-location-on-google-maps-heres-how-article-106474116
# ...

# %%
data = []

# Loop through each article URL and extract <h1> elements and contents
for article_url in article_urls:
    article_response = requests.get(article_url)
    article_soup = BeautifulSoup(article_response.text, 'html.parser')
    
    # Find all <h1> elements with class 'class="QA-A P0ju _3RAT"'
    article_h1_elements = article_soup.find_all('h1', class_='QA-A P0ju _3RAT')
    
    # Extracting text from the <h1> elements
    for h1_element in article_h1_elements:
        heading = h1_element.text.strip()
        
        # Find the content based on the heading
        content = ''
        content_div = h1_element.find_next(class_='QA-A P0ju _3RAT')
        if content_div:
            content = content_div.text.strip()
        
        # Append the heading and content as a tuple to the data list
        data.append((heading, content))

# Specify the CSV file name
csv_filename = 'headings_contents.csv'

# Writing data to CSV file
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    # Write header row
    writer.writerow(['Heading', 'Content'])
    # Write rows of heading and content pairs
    writer.writerows(data)

print(f"Data has been saved to '{csv_filename}'.")
# Out:
# Data has been saved to 'headings_contents.csv'.

# %%
url = 'https://www.timesnownews.com/latest-news'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <a> elements with class 'undefined'
article_links = soup.find_all('a', class_='undefined')

# Extracting href attribute values from article links
article_urls = [link.get('href') for link in article_links]

# Create a list to store headings and contents
data = []

# Function to extract heading and content from an article URL
def extract_data(article_url):
    article_response = requests.get(article_url)
    article_soup = BeautifulSoup(article_response.text, 'html.parser')
    
    # Find <h1> element as heading
    heading = article_soup.find('h1').text.strip()
    
    # Find elements with class 'QA-A P0ju _3RAT' as content
    content_elements = article_soup.find_all(class_='QA-A P0ju _3RAT')
    content = '\n'.join([elem.text.strip() for elem in content_elements])
    
    data.append((heading, content))

# Loop through each article URL and extract data
for article_url in article_urls:
    extract_data(article_url)

# Specify the CSV file name
csv_filename = 'headings_contents.csv'

# Writing data to CSV file
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    # Write header row
    writer.writerow(['Heading', 'Content'])
    # Write rows of heading and content pairs
    writer.writerows(data)

print(f"Data has been saved to '{csv_filename}'.")
# Out:
# Data has been saved to 'headings_contents.csv'.

# %%
TMN1 =  pd.read_csv('headings_contents.csv')
TMN1
# Out:
#                                               Heading  \
# 0   POCO X6 Series Launch Date In India Revealed: ...
# 1   Ira Khan, Nupur Shikhare Wedding: Reena Dutta,...
# 2   Jeremy Renner Recalls HORRIFIC Snowplow Accide...
# 3   'Thok Dijiye Sir...': Why No Bulldozer Action ...
# 4   Pakistan Make Surprising Change In AUS vs PAK ...
# 5   How to Check if Someone Has Blocked You on Ins...
# 6   Filled A Cybercrime Complaint? Here's How To C...
# 7   Filled A Cybercrime Complaint? Here's How To C...
# 8   Pakistan Awaits USD 700 Million IMF Tranche, D...
# 9   New Parents Rubina Dilaik-Abhinav Shukla Hold ...
# 10  Forget WhatsApp! Share Live Location on Google...
# 11  GRAP-3 Restrictions Lifted, You Can Now Drive ...
# 12  Tarot Card Reading for Today; January 2: Expen...
# 13  Nargis Fakhri Kicks Off 2024 With Rumoured Bea...
# 14  150 to 100 Meters: Delhi Reduces Distance Gap ...
# 15  George RR Martin Shares BIG Update About Game ...
# ...

# %%
url = 'https://www.timesnownews.com/india'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <a> elements with class 'undefined'
article_links = soup.find_all('a', class_='undefined')

# Extracting href attribute values from article links
article_urls = [link.get('href') for link in article_links]

# Create a list to store headings and contents
data = []

# Function to extract heading and content from an article URL
def extract_data(article_url):
    article_response = requests.get(article_url)
    article_soup = BeautifulSoup(article_response.text, 'html.parser')
    
    # Find <h1> element as heading
    heading = article_soup.find('h1').text.strip()
    
    # Find elements with class 'QA-A P0ju _3RAT' as content
    content_elements = article_soup.find_all(class_='QA-A P0ju _3RAT')
    content = '\n'.join([elem.text.strip() for elem in content_elements])
    
    data.append((heading, content))

# Loop through each article URL and extract data
for article_url in article_urls:
    extract_data(article_url)

# Specify the CSV file name
csv_filename = 'headings_contentss.csv'

# Writing data to CSV file
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    # Write header row
    writer.writerow(['Heading', 'Content'])
    # Write rows of heading and content pairs
    writer.writerows(data)

print(f"Data has been saved to '{csv_filename}'.")
# Out:
# Data has been saved to 'headings_contentss.csv'.

# %%
TMN2 =  pd.read_csv('headings_contentss.csv')
TMN2
# Out:
#                                               Heading  \
# 0   'Thok Dijiye Sir...': Why No Bulldozer Action ...
# 1   India Records 573 Covid Cases In 24 Hours, Act...
# 2   Father Jumps To Death From Metro Station After...
# 3   Meet Arun Yogiraj: From Adi Shankaracharya In ...
# 4   WATCH | Road Signs, Display Boards At Metro St...
# ..                                                ...
# 65  Pune: Long Queues Seen At Petrol Pumps Amid Dr...
# 66  Truck Drivers Halt Highways In 'Chakka Jam' Ag...
# 67  Pune Airport Traffic Likely to Hit All-Time Hi...
# 68  New Year Celebrations in Pune: Traffic Advisor...
# 69  Pune Traffic Advisory Issued For Bhima Koregao...
#
#                                               Content
# 0   Three persons have been arrested in the IIT-BH...
# 1                                                 NaN
# 2   ​​The man -- Gaurav Sharma -- was on the run a...
# 3   Although he pursued a degree in MBA for a brie...
# ...

# %%
url = 'https://www.timesnownews.com/entertainment-news'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <a> elements with class 'undefined'
article_links = soup.find_all('a', class_='undefined')

# Extracting href attribute values from article links
article_urls = [link.get('href') for link in article_links]

# Create a list to store headings and contents
data = []

# Function to extract heading and content from an article URL
def extract_data(article_url):
    article_response = requests.get(article_url)
    article_soup = BeautifulSoup(article_response.text, 'html.parser')
    
    # Find <h1> element as heading
    heading = article_soup.find('h1').text.strip()
    
    # Find elements with class 'QA-A P0ju _3RAT' as content
    content_elements = article_soup.find_all(class_='QA-A P0ju _3RAT')
    content = '\n'.join([elem.text.strip() for elem in content_elements])
    
    data.append((heading, content))

# Loop through each article URL and extract data
for article_url in article_urls:
    extract_data(article_url)

# Specify the CSV file name
csv_filename = 'headings_contentsss.csv'

# Writing data to CSV file
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    # Write header row
    writer.writerow(['Heading', 'Content'])
    # Write rows of heading and content pairs
    writer.writerows(data)

print(f"Data has been saved to '{csv_filename}'.")
# Out:
# Data has been saved to 'headings_contentsss.csv'.

# %%
url = 'https://www.timesnownews.com/business-economy'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <a> elements with class 'undefined'
article_links = soup.find_all('a', class_='undefined')

# Extracting href attribute values from article links
article_urls = [link.get('href') for link in article_links]

# Create a list to store headings and contents
data = []

# Function to extract heading and content from an article URL
def extract_data(article_url):
    article_response = requests.get(article_url)
    article_soup = BeautifulSoup(article_response.text, 'html.parser')
    
    # Find <h1> element as heading
    heading = article_soup.find('h1').text.strip()
    
    # Find elements with class 'QA-A P0ju _3RAT' as content
    content_elements = article_soup.find_all(class_='QA-A P0ju _3RAT')
    content = '\n'.join([elem.text.strip() for elem in content_elements])
    
    data.append((heading, content))

# Loop through each article URL and extract data
for article_url in article_urls:
    extract_data(article_url)

# Specify the CSV file name
csv_filename = 'headings_contentssss.csv'

# Writing data to CSV file
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    # Write header row
    writer.writerow(['Heading', 'Content'])
    # Write rows of heading and content pairs
    writer.writerows(data)

print(f"Data has been saved to '{csv_filename}'.")
# Out:
# Data has been saved to 'headings_contentssss.csv'.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="THIn.jpg">
#         </td>
#         <td>
#         </td>
#     </tr>
# </table>

# %%
url = 'https://www.thehindu.com/latest-news/'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <h3> elements with class 'title' to extract article URLs
article_links = soup.find_all('h3', class_='title')

# Extracting href attribute values from article links
article_urls = [link.find('a').get('href') for link in article_links]

# Create a list to store headings and contents
data = []

# Function to extract heading and content from an article URL
def extract_data(article_url):
    article_response = requests.get(article_url)
    article_soup = BeautifulSoup(article_response.text, 'html.parser')
    
    # Find <h1> element as heading
    heading = article_soup.find('h1', class_='title').text.strip()
    
    # Find elements with class 'sub-title' as content
    content_elements = article_soup.find_all('h3', class_='sub-title')
    content = '\n'.join([elem.text.strip() for elem in content_elements])
    
    data.append((heading, content))

# Loop through each article URL and extract data
for article_url in article_urls:
    extract_data(article_url)

# Specify the CSV file name
csv_filename = 'headings_contents_thehindu.csv'

# Writing data to CSV file
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    # Write header row
    writer.writerow(['Heading', 'Content'])
    # Write rows of heading and content pairs
    writer.writerows(data)

print(f"Data has been saved to '{csv_filename}'.")
# Out:
# Data has been saved to 'headings_contents_thehindu.csv'.

# %%
Hindu = pd.read_csv('headings_contents_thehindu.csv')
Hindu
# Out:
#                                                Heading  \
# 0    Indian youths are creating a brave new world: ...
# 1               What to expect in smartphones in 2024?
# 2    Water bodies across Kashmir freeze, minimum te...
# 3    Premier League | Liverpool go 3 points clear o...
# 4    SC declines to intervene on DMK’s signature ca...
# ..                                                 ...
# 195   DC reviews COVID-19 situation in Mysuru district
# 196  Dip in beer sales during Christmas and New Yea...
# 197  Govt. plans to make all family health centres ...
# 198  NCC organises annual training camp at Kendriya...
# 199  Kerala High Court confirms life term awarded t...
#
#                                                Content
# 0    PM Modi is the first prime Minister to address...
# 1    Realme and Oppo gear themselves for GT series ...
# 2    A thin layer of ice has formed over the surfac...
# 3    Salah, who has 150 Premier League goals for Li...
# ...

# %%
url = 'https://www.thehindu.com/news/international/'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <h3> elements with class 'title' to extract article URLs
article_links = soup.find_all('h3', class_='title')

# Extracting href attribute values from article links
article_urls = [link.find('a').get('href') for link in article_links]

# Create a list to store headings and contents
data = []

# Function to extract heading and content from an article URL
def extract_data(article_url):
    article_response = requests.get(article_url)
    article_soup = BeautifulSoup(article_response.text, 'html.parser')
    
    # Find <h1> element as heading
    heading = article_soup.find('h1', class_='title').text.strip()
    
    # Find elements with class 'sub-title' as content
    content_elements = article_soup.find_all('h3', class_='sub-title')
    content = '\n'.join([elem.text.strip() for elem in content_elements])
    
    data.append((heading, content))

# Loop through each article URL and extract data
for article_url in article_urls:
    extract_data(article_url)

# Specify the CSV file name
csv_filename = 'headings_contents_thehindu1.csv'

# Writing data to CSV file
with open(csv_filename, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    # Write header row
    writer.writerow(['Heading', 'Content'])
    # Write rows of heading and content pairs
    writer.writerows(data)

print(f"Data has been saved to '{csv_filename}'.")
# Out:
# Data has been saved to 'headings_contents_thehindu1.csv'.
